# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
data=pd.read_csv(r"C:\Users\lenov\Downloads\Advertising.csv")
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
from pandas_profiling import ProfileReport

# %%
df=ProfileReport(data)
df
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-10-28 05:54:38.586586&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
x=data[['TV','Radio','Newspaper']]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=data.Sales
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_data=scaler.fit_transform(x)

# %%
x_data
# Out:
# array([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00],
#        [-1.19737623e+00,  1.08280781e+00,  6.69578760e-01],
#        [-1.51615499e+00,  1.52846331e+00,  1.78354865e+00],
#        [ 5.20496822e-02,  1.21785493e+00,  1.28640506e+00],
#        [ 3.94182198e-01, -8.41613655e-01,  1.28180188e+00],
#        [-1.61540845e+00,  1.73103399e+00,  2.04592999e+00],
#        [-1.04557682e+00,  6.43904671e-01, -3.24708413e-01],
#        [-3.13436589e-01, -2.47406325e-01, -8.72486994e-01],
#        [-1.61657614e+00, -1.42906863e+00, -1.36042422e+00],
#        [ 6.16042873e-01, -1.39530685e+00, -4.30581584e-01],
#        [-9.45155670e-01, -1.17923146e+00, -2.92486143e-01],
#        [ 7.90028350e-01,  4.96973404e-02, -1.22232878e+00],
#        [-1.43908760e+00,  7.99208859e-01,  1.62704048e+00],
#        [-5.78501712e-01, -1.05768905e+00, -1.07502697e+00],
#        [ 6.66253447e-01,  6.50657027e-01,  7.11007392e-01],
#        [ 5.64664612e-01,  1.65000572e+00,  1.02862691e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
linear=LinearRegression()

# %%
linear.fit(x,y)
# Out:
# LinearRegression()

# %%
linear.fit(x_data,y)
# Out:
# LinearRegression()

# %%
linear.intercept_
# Out:
# 14.0225

# %%
linear.coef_
# Out:
# array([ 3.91925365,  2.79206274, -0.02253861])

# %%
linear.score(x_data,y)
# Out:
# 0.8972106381789522

# %%
linear.score(x,y)
# Out:
# C:\Users\lenov\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -19316.254888347197

# %%
linear.predict([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00]])
# Out:
# array([20.52397441])

# %%
linear.predict([[230.1,37.8,69.2]])
# Out:
# C:\Users\lenov\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.52397441])

# %%
import statsmodels.formula.api as smf

# %%
lm=smf.ols(formula='y~x',data=data).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Fri, 28 Oct 2022   Prob (F-statistic):           1.58e-96
# Time:                        11:44:31   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
lm=smf.ols(formula='y~x_data',data=data).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Fri, 28 Oct 2022   Prob (F-statistic):           1.58e-96
# Time:                        11:45:31   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     14.0225      0.119    117.655      0.000      13.787      14.258
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(data)
